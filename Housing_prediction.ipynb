# %%
import pandas as pd
import os

# %%
os.getcwd()
os.listdir(os.getcwd()+r'/housingdata')
# Out:
# ['test.csv', 'train.csv']

# %%
train_df = pd.read_csv('./housingdata/train.csv')
test_df = pd.read_csv('./housingdata/test.csv')

# %%
print([len(x) for x in (train_df, test_df)])
# Out:
# [1460, 1459]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#combine both train and set to one big data for cleaning and data exploration
combined_df = pd.concat([train_df, test_df])

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %%
pd.set_option('display.max_columns', None)
combined_df.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %% [markdown]
# Data Cleaning

# %%
print(combined_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %%
combined_df.MSSubClass.dtypes
# Out:
# dtype('int64')

# %%
combined_df.MoSold.dtypes
# Out:
# dtype('int64')

# %%
combined_df['MSSubClass'] = combined_df['MSSubClass'].astype('category')
combined_df['MoSold'] = combined_df['MoSold'].astype('category')

# %%
combined_df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# PoolQC          2909
# MiscFeature     2814
# Alley           2721
# Fence           2348
# MasVnrType      1766
# SalePrice       1459
# FireplaceQu     1420
# LotFrontage      486
# GarageYrBlt      159
# GarageFinish     159
# GarageQual       159
# GarageCond       159
# GarageType       157
# BsmtExposure      82
# BsmtCond          82
# BsmtQual          81
# BsmtFinType2      80
# BsmtFinType1      79
# MasVnrArea        23
# MSZoning           4
# dtype: int64

# %%
len(combined_df)
# Out:
# 2919

# %% [markdown]
# Cleaning categorical variables

# %%
combined_df = combined_df.drop(['PoolQC', 'MiscFeature', 'Alley'], axis=1)

# %%
combined_df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# Fence           2348
# MasVnrType      1766
# SalePrice       1459
# FireplaceQu     1420
# LotFrontage      486
# GarageCond       159
# GarageYrBlt      159
# GarageFinish     159
# GarageQual       159
# GarageType       157
# BsmtExposure      82
# BsmtCond          82
# BsmtQual          81
# BsmtFinType2      80
# BsmtFinType1      79
# MasVnrArea        23
# MSZoning           4
# BsmtHalfBath       2
# BsmtFullBath       2
# Utilities          2
# dtype: int64

# %%
combined_df.Utilities
# Out:
# 0       AllPub
# 1       AllPub
# 2       AllPub
# 3       AllPub
# 4       AllPub
#          ...
# 1454    AllPub
# 1455    AllPub
# 1456    AllPub
# 1457    AllPub
# 1458    AllPub
# Name: Utilities, Length: 2919, dtype: object

# %%
combined_df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
#                  ...
# MoSold              0
# YrSold              0
# SaleType            1
# SaleCondition       0
# SalePrice        1459
# Length: 78, dtype: int64

# %%
import numpy as np
features = combined_df.columns.groupby(combined_df.dtypes)
features_dict = dict(features)
#for i in features_dict[np.dtype('O')]
for missing_val in features_dict[np.dtype('O')]:
    try:
        combined_df[missing_val] = combined_df.groupby(['MSSubClass', 'Neighborhood'],observed=False)[missing_val].transform(lambda x: x.fillna(x.mode()[0]))
    except:
        combined_df[missing_val] = combined_df[missing_val].fillna(combined_df[missing_val].mode()[0])

# %%
combined_df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# SalePrice        1459
# LotFrontage       486
# GarageYrBlt       159
# MasVnrArea         23
# BsmtFullBath        2
# BsmtHalfBath        2
# TotalBsmtSF         1
# BsmtUnfSF           1
# BsmtFinSF2          1
# BsmtFinSF1          1
# GarageCars          1
# GarageArea          1
# KitchenAbvGr        0
# Functional          0
# TotRmsAbvGrd        0
# KitchenQual         0
# SaleCondition       0
# BedroomAbvGr        0
# HalfBath            0
# Fireplaces          0
# dtype: int64

# %%
features_dict = dict(features)
features_dict[np.dtype(np.int64)]
# Out:
# Index(['Id', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'YrSold'],
#       dtype='object')

# %%
for missing_val in ['MSSubClass', 'MoSold']:
    try:
        combined_df[missing_val] = combined_df.groupby(['MSSubClass', 'Neighborhood'],observed=False)[missing_val].transform(lambda x: x.fillna(x.mode()[0]))
    except:
        combined_df[missing_val] = combined_df[missing_val].fillna(combined_df[missing_val].mode()[0])

# %%
combined_df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# SalePrice        1459
# LotFrontage       486
# GarageYrBlt       159
# MasVnrArea         23
# BsmtFullBath        2
# BsmtHalfBath        2
# TotalBsmtSF         1
# BsmtUnfSF           1
# BsmtFinSF2          1
# BsmtFinSF1          1
# GarageCars          1
# GarageArea          1
# KitchenAbvGr        0
# Functional          0
# TotRmsAbvGrd        0
# KitchenQual         0
# SaleCondition       0
# BedroomAbvGr        0
# HalfBath            0
# Fireplaces          0
# dtype: int64

# %%
numeric_cols = combined_df.select_dtypes(include=np.number).columns

# %%
combined_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
missing_vals = ["LotFrontage", 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF1','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageCars', 'GarageArea',]
impute_vals = ["LotConfig" ,"Neighborhood",'BsmtFinType1', 'BsmtFinType2','BsmtQual', 'BsmtQual', 'BsmtQual','GarageType', 'GarageType']

for missing_val, impute_val in zip(missing_vals, impute_vals):
    combined_df[missing_val] = combined_df[missing_val].fillna(combined_df.groupby(impute_val)[missing_val].transform('mean'))

#for missing_val, impute_val in zip(missing_vals, impute_vals):
#    combined_df[missing_val] = combined_df[missing_val].groupby(impute_val)[missing_val].transform(lambda x: x.fillna(x.mean()))

# %%
combined_df.isnull().sum().sort_values(ascending=False)
# Out:
# SalePrice        1459
# GarageYrBlt       159
# BsmtUnfSF           1
# BsmtFinSF2          1
# SaleCondition       0
#                  ...
# MasVnrType          0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# HeatingQC           0
# Length: 78, dtype: int64

# %%
combined_df['GarageYrBlt'] = combined_df['GarageYrBlt'].fillna(combined_df['YearBuilt'])

# %%
for missing_val in combined_df.columns.values.tolist():
    if missing_val == 'SalePrice':
        pass
    else:
        try:
            combined_df[missing_val] = combined_df[missing_val].fillna(combined_df[missing_val].mean())
        except:
            pass

# %%
#This will return SalePrice the only label that we want to predict
print([col for col in combined_df.columns.to_numpy() if combined_df[col].isnull().any()])
# Out:
# ['SalePrice']

# %% [markdown]
# Feature Engenerring

# %%
# change built year to age of the house
import datetime
year = datetime.date.today().year

combined_df['AgeSold'] =  int(year) - combined_df['YrSold'].astype('int64')
combined_df['AgeGarage'] = int(year) - combined_df['GarageYrBlt'].astype('int64')
combined_df['AgeBuilt'] = int(year) - combined_df['YearBuilt'].astype('int64')

# %%
#add some features related to the total surface of the house
combined_df['TotalArea'] = combined_df['TotalBsmtSF'] + combined_df['1stFlrSF'] + combined_df['2ndFlrSF'] + combined_df['GrLivArea'] +combined_df['GarageArea']
combined_df['Bathrooms'] = combined_df['FullBath'] + combined_df['HalfBath']/2
combined_df['Year average']= (combined_df['YearRemodAdd']+combined_df['YearBuilt'])/2

# %%
combined_df.drop(['YrSold', 'GarageYrBlt', 'YearBuilt'], axis=1, inplace=True)

# %% [markdown]
# ###IV. Plotting

# %%
catergoryType = [caType for caType in combined_df.columns if combined_df[caType].dtypes == 'category']
catergoryType
# Out:
# ['MSSubClass', 'MoSold']

# %%
import seaborn as sns

for feature in ["MSSubClass", "MSZoning", "HouseStyle","CentralAir", "SaleType"]:
    cat_plot = sns.catplot(y='SalePrice', x=feature, data=combined_df, height=4.5, aspect=3 / 3)

# %%
combined_df[[x for x in combined_df.columns if combined_df[x].dtype==np.dtype('O')]]
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1454       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1455       RM   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Mod
#
#      Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle  \
# ...

# %%
# Check the sale price distribution by different types of variables
for element in ["1stFlrSF", "LotArea", "OverallQual", "OverallCond", "YearBuilt","ExterQual", "YrSold"]:
    re_plot = sns.relplot(y="SalePrice", x= element, legend="full", data=combined_df, height=4.5, aspect=3 / 3,);
    re_plot.set_xticklabels(rotation=90)
# Out:
# d:\Softwares\Linux\Anacoda3\envs\ml\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# d:\Softwares\Linux\Anacoda3\envs\ml\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# d:\Softwares\Linux\Anacoda3\envs\ml\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# d:\Softwares\Linux\Anacoda3\envs\ml\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# d:\Softwares\Linux\Anacoda3\envs\ml\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ...

# %%
corr_mat = combined_df[[x for x in combined_df.columns if combined_df[x].dtype==np.number]].corr()
# Out:
# <ipython-input-40-186233180c9c>:1: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   corr_mat = combined_df[[x for x in combined_df.columns if combined_df[x].dtype==np.number]].corr()

# %%
sns.heatmap(corr_mat, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# V. Data transformation

# %%
# Get dummies for data set
combined_df = pd.get_dummies(combined_df)

# %%
combined_df.head()
# Out:
#    Id  LotFrontage  LotArea  OverallQual  OverallCond  YearRemodAdd  \
# 0   1         65.0     8450            7            5          2003
# 1   2         80.0     9600            6            8          1976
# 2   3         68.0    11250            7            5          2002
# 3   4         60.0     9550            7            5          1970
# 4   5         84.0    14260            8            5          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0       196.0       706.0         0.0      150.0        856.0       856
# 1         0.0       978.0         0.0      284.0       1262.0      1262
# 2       162.0       486.0         0.0      434.0        920.0       920
# 3         0.0       216.0         0.0      540.0        756.0       961
# 4       350.0       655.0         0.0      490.0       1145.0      1145
#
#    2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  \
# ...

# %%
#Split data set into test and train
pd.options.mode.copy_on_write = True
train_df = combined_df[combined_df['SalePrice'] > 0]
test_df = combined_df[combined_df['SalePrice'].isnull()]
test_df.drop('SalePrice', axis=1, inplace=True)

# %%
# Create X and y sets
X_train_df = train_df.drop('SalePrice', axis=1)
y_train_df = train_df[['Id', 'SalePrice']]

# %%
y_train_df['SalePrice'].skew(), y_train_df['SalePrice'].kurt()
# Out:
# (1.8828757597682129, 6.536281860064529)

# %%
y_train_df['SalePrice'] = np.log(y_train_df['SalePrice'])

# %%
import seaborn as sns
sns.histplot(y_train_df['SalePrice'])
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
y_train_df['SalePrice'].skew()
# Out:
# 0.12133506220520406

# %%
len(X_train_df), len(y_train_df)
# Out:
# (1460, 1460)

# %%
test_df.head()
# Out:
#      Id  LotFrontage  LotArea  OverallQual  OverallCond  YearRemodAdd  \
# 0  1461         80.0    11622            5            6          1961
# 1  1462         81.0    14267            6            6          1958
# 2  1463         74.0    13830            5            5          1998
# 3  1464         78.0     9978            6            6          1998
# 4  1465         43.0     5005            8            5          1992
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0         0.0       468.0       144.0      270.0        882.0       896
# 1       108.0       923.0         0.0      406.0       1329.0      1329
# 2         0.0       791.0         0.0      137.0        928.0       928
# 3        20.0       602.0         0.0      324.0        926.0       926
# 4         0.0       263.0         0.0     1017.0       1280.0      1280
#
#    2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  \
# ...

# %%
# Set Id as index
for dataset in [X_train_df, y_train_df, test_df]:
    dataset.set_index('Id', inplace=True)

# %%
X_train_df.head()
# Out:
#     LotFrontage  LotArea  OverallQual  OverallCond  YearRemodAdd  MasVnrArea  \
# Id
# 1          65.0     8450            7            5          2003       196.0
# 2          80.0     9600            6            8          1976         0.0
# 3          68.0    11250            7            5          2002       162.0
# 4          60.0     9550            7            5          1970         0.0
# 5          84.0    14260            8            5          2000       350.0
#
#     BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# Id
# 1        706.0         0.0      150.0        856.0       856       854
# 2        978.0         0.0      284.0       1262.0      1262         0
# 3        486.0         0.0      434.0        920.0       920       866
# 4        216.0         0.0      540.0        756.0       961       756
# 5        655.0         0.0      490.0       1145.0      1145      1053
#
# ...

# %% [markdown]
# #Scale the data

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

X_train_scaled = scaler.fit_transform(X_train_df)

### features for prediction of unknown SalePrice
X_test_scaled = scaler.fit_transform(test_df)

# %%
y_train_df = y_train_df.to_numpy()
y_train_df.shape
# Out:
# (1460, 1)

# %% [markdown]
# VI. Modelling

# %%
X_train_scaled
# Out:
# array([[-0.11028464, -0.25407609,  0.5       , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.63971536,  0.03001482,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.03971536,  0.43762352,  0.5       , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.06028464, -0.10783103,  0.5       , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.03971536,  0.05891798, -0.5       , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.38971536,  0.11326581, -0.5       , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_train_scaled, y_train_df, test_size=0.05, random_state=23)

# %%
# convert y_train from a shape of (n_sample, 1) to a 1-dimenstional array (n_sample,)
y_train = y_train.ravel() # Alternatively, you can use y_train.flatten()
y_train.shape
# Out:
# (1387,)

# %%
#Regulation with Elastic Net
from sklearn.linear_model import ElasticNetCV
from sklearn.metrics import mean_squared_error
from math import sqrt

alphas = [0.0001, 0.000542555, 0.001, 0.005, 0.01, 0.1]
l1ratio = [0.1, 0.3, 0.5, 0.9, 0.95, 0.99, 1]

elastic_cv = ElasticNetCV(cv=5, max_iter=100000, alphas=alphas, l1_ratio=l1ratio)

elastic_reg = elastic_cv.fit(X_train, y_train)

y_pred = elastic_reg.predict(X_test)

print("ElasticRegression RMSE:", sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# ElasticRegression RMSE: 0.1439313985757928

# %%
X_test
# Out:
# array([[ 0.78971536,  0.23258399,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.59523221,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 2.83971536,  0.50234684,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.        ,  0.10412549,  0.5       , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.48971536, -0.21875   , -1.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.63971536,  0.32472826, -0.5       , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
# Print the best alpha and l1_ratio
print(f"Best alpha: {elastic_cv.alpha_}")
print(f"Best l1_ratio: {elastic_cv.l1_ratio_}")

# Print all parameters of the optimal model
print("Best parameters found by ElasticNetCV:")
print(elastic_cv.get_params())
# Out:
# Best alpha: 0.000542555
# Best l1_ratio: 0.9
# Best parameters found by ElasticNetCV:
# {'alphas': [0.0001, 0.000542555, 0.001, 0.005, 0.01, 0.1], 'copy_X': True, 'cv': 5, 'eps': 0.001, 'fit_intercept': True, 'l1_ratio': [0.1, 0.3, 0.5, 0.9, 0.95, 0.99, 1], 'max_iter': 100000, 'n_alphas': 100, 'n_jobs': None, 'positive': False, 'precompute': 'auto', 'random_state': None, 'selection': 'cyclic', 'tol': 0.0001, 'verbose': 0}

# %%
predictions = np.exp(elastic_reg.predict(X_test_scaled))

my_prediction = pd.DataFrame({'Id':test_df.index, "SalePrice":predictions})

# %%
my_prediction
# Out:
#         Id      SalePrice
# 0     1461  122120.746067
# 1     1462  146065.529849
# 2     1463  178367.548258
# 3     1464  203652.618532
# 4     1465  207889.666897
# ...    ...            ...
# 1454  2915   88435.212101
# 1455  2916   86626.432485
# 1456  2917  165246.779898
# 1457  2918  121490.959114
# 1458  2919  232509.446359
#
# [1459 rows x 2 columns]

# %%
#Lasso
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

parameters = {'alpha':[0.0001,0.0002,0.0005,0.0009,0.001,0.002,0.003,0.01,0.1,1,10,100]}

lasso = Lasso(max_iter=100000)

lasso_search = GridSearchCV(lasso, param_grid=parameters, scoring='neg_mean_squared_error', cv=5)

lasso_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(max_iter=100000),
#              param_grid={'alpha': [0.0001, 0.0002, 0.0005, 0.0009, 0.001, 0.002,
#                                    0.003, 0.01, 0.1, 1, 10, 100]},
#              scoring='neg_mean_squared_error')

# %%
print(lasso_search.best_params_)
# Out:
# {'alpha': 0.0005}

# %%
lasso_search.cv_results_
# Out:
# {'mean_fit_time': array([2.9442729 , 1.51069031, 0.57829657, 0.20651255, 0.21641831,
#         0.06827922, 0.08935251, 0.03926754, 0.01504188, 0.01051307,
#         0.00941205, 0.00899019]),
#  'std_fit_time': array([2.59453957e-01, 2.63123169e-01, 1.48727787e-01, 1.59781182e-02,
#         5.53072733e-02, 1.06068201e-02, 2.20825154e-02, 3.67275179e-03,
#         6.08038962e-04, 1.87030935e-03, 2.57386963e-04, 8.81534847e-04]),
#  'mean_score_time': array([0.00109372, 0.00175529, 0.00175743, 0.0013792 , 0.00150442,
#         0.00128837, 0.00184402, 0.00134068, 0.00161171, 0.00145988,
#         0.0019115 , 0.00138197]),
#  'std_score_time': array([0.00027148, 0.0004284 , 0.00067225, 0.00041893, 0.00031431,
#         0.00053125, 0.00078936, 0.00042477, 0.00035067, 0.00083198,
#         0.00065797, 0.00024899]),
#  'param_alpha': masked_array(data=[0.0001, 0.0002, 0.0005, 0.0009, 0.001, 0.002, 0.003,
#                     0.01, 0.1, 1.0, 10.0, 100.0],
# ...

# %%
from math import sqrt

y_pred = lasso_search.predict(X_test)

print('LassoRegressor RMSE:', sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# LassoRegressor RMSE: 0.14366179809818022

# %%
#This is to test the mode by using the optimal parameters obtained from GridSearchCV
lasso_reg = Lasso(alpha=0.0005,max_iter=100000)

lasso_reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.0005, max_iter=100000)

# %%
y_pred2 = lasso_reg.predict(X_test)

# %%
from sklearn.metrics import root_mean_squared_error
print('LassoRegressor RMSE:', root_mean_squared_error(y_test,y_pred))
# Out:
# LassoRegressor RMSE: 0.14366179010553154

# %%
## Predict Sale values

predictions_lasso = np.exp(lasso_search.predict(X_test_scaled))

my_prediction_lasso = pd.DataFrame({'Id':test_df.index, 'SalePrice':predictions_lasso})

# %%
my_prediction_lasso
# Out:
#         Id      SalePrice
# 0     1461  122671.084912
# 1     1462  146278.557257
# 2     1463  178686.079808
# 3     1464  203918.043470
# 4     1465  207693.469975
# ...    ...            ...
# 1454  2915   88763.124127
# 1455  2916   86638.755929
# 1456  2917  165912.768291
# 1457  2918  121868.122235
# 1458  2919  232622.460750
#
# [1459 rows x 2 columns]

# %% [markdown]
# RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': ['auto', 'sqrt', 'log2'],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}


rf = RandomForestRegressor()

grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 5, n_jobs = -1, verbose = 2)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-7eedf5c85101> in <cell line: 18>()
#      16
#      17 # Fit the grid search to the data
# ---> 18 grid_search.fit(X_train, y_train)
#      19 print(grid_search.best_params_)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1017                 return results
#    1018
# -> 1019             self._run_search(evaluate_candidates)
#    1020
# ...

# %%
rf_reg = RandomForestRegressor(bootstrap=True, max_depth=80, max_features='sqrt', min_samples_leaf=3, min_samples_split=8, n_estimators=300, n_jobs=2, random_state=12)

#Fit the model to data
rf_reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=80, max_features='sqrt', min_samples_leaf=3,
#                       min_samples_split=8, n_estimators=300, n_jobs=2,
#                       random_state=12)

# %%
from sklearn.metrics import root_mean_squared_error
y_pred_rf = rf_reg.predict(X_test)
print('RandomForestRegressor RMSE:', root_mean_squared_error(y_test, y_pred_rf))
# Out:
# RandomForestRegressor RMSE: 0.2005147327656442

# %%
predictions_rf = np.exp(rf_reg.predict(X_test_scaled))

my_prediction_rf = pd.DataFrame({'Id': test_df.index, 'SalePrice':predictions_rf })

my_prediction_rf
# Out:
#         Id      SalePrice
# 0     1461  127054.263095
# 1     1462  156063.965142
# 2     1463  184124.203749
# 3     1464  188597.737498
# 4     1465  196435.282918
# ...    ...            ...
# 1454  2915   96506.038201
# 1455  2916  100998.835304
# 1456  2917  159446.782147
# 1457  2918  125116.051154
# 1458  2919  223771.907565
#
# [1459 rows x 2 columns]

# %% [markdown]
# AdaBoost

# %%
# ADA BOOST
from sklearn.ensemble import AdaBoostRegressor

# Grid search for best params
param_grid = {
 'n_estimators': [50, 100, 200],
 'learning_rate' : [0.01,0.05,0.1,0.3,1],
 'loss' : ['linear', 'square', 'exponential']
 }

# Instantiate reg for gridsearch
ab_reg = AdaBoostRegressor()

# Conduct the gridsearch
grid_search = GridSearchCV(estimator = ab_reg, param_grid = param_grid, cv = 4, n_jobs = -1, verbose = 2)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)

# Create a random forest with best parameters
ab_reg = AdaBoostRegressor(learning_rate =1, loss = 'exponential', n_estimators =  50, random_state= 12)

# Fit the model to the data
ab_reg.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 45 candidates, totalling 180 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-4880b347c3bd> in <cell line: 18>()
#      16
#      17 # Fit the grid search to the data
# ---> 18 grid_search.fit(X_train, y_train)
#      19 print(grid_search.best_params_)
#      20
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1017                 return results
#    1018
# -> 1019             self._run_search(evaluate_candidates)
#    1020
# ...

# %%
# Predict on the test set from our training set
y_pred_ab = ab_reg.predict(X_test)
print("AdaBoostRegressor RMSE:",root_mean_squared_error(y_test, y_pred_ab))

# Create predictions
predictions = np.exp(ab_reg.predict(X_test_scaled))
my_pred_ab = pd.DataFrame({'Id': test_df.index, 'SalePrice': predictions})

# Create CSV file
#my_pred_ab.to_csv('pred_ab.csv', index=False)
my_pred_ab
# Out:
# AdaBoostRegressor RMSE: 0.19595561323283064
#         Id      SalePrice
# 0     1461  114134.328843
# 1     1462  149258.415172
# 2     1463  157585.957612
# 3     1464  177440.156059
# 4     1465  179328.532963
# ...    ...            ...
# 1454  2915   82755.924626
# 1455  2916   94568.027671
# 1456  2917  142847.288325
# 1457  2918  112292.669035
# 1458  2919  201151.804404
#
# [1459 rows x 2 columns]

# %%
# XGBOOST
from xgboost import XGBRegressor

# Grid search for best params
param_grid = {'max_depth':[3,4],
          'learning_rate':[0.01,0.03],
          'min_child_weight':[1,3],
          'reg_lambda':[0.1,0.5],
          'reg_alpha':[1,1.5],
          'gamma':[0.1,0.5],
          'subsample':[0.4,0.5],
         'colsample_bytree':[0.4,0.5],
}

# Instantiate reg for gridsearch
reg = XGBRegressor()

# Conduct the gridsearch
grid_search = GridSearchCV(estimator = reg, param_grid = param_grid,
                          cv = 4, n_jobs = -1, verbose = True)

# Fit the grid search to the data
grid_search.fit(X_train_df, y_train_df)
print(grid_search.best_params_)

# Create a regressor with best parameters
xgb_reg = XGBRegressor(learning_rate=0.01,n_estimators=3460,
                                     max_depth=3,min_child_weight=0,
                                     gamma=0, subsample=0.7,
                                     colsample_bytree=0.7,
                                     objective='reg:squarederror',
nthread=2, scale_pos_weight=1, seed=27,reg_alpha=0.00006)

# Fit the model to the data
xgb_reg.fit(X_train, y_train)

# Predict on the test set from our training set
y_pred = xgb_reg.predict(X_test)
print("XGBoostRegressor RMSE:",root_mean_squared_error(y_test, y_pred))
# Out:
# Fitting 4 folds for each of 256 candidates, totalling 1024 fits
# {'colsample_bytree': 0.5, 'gamma': 0.1, 'learning_rate': 0.03, 'max_depth': 4, 'min_child_weight': 1, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 0.5}
# XGBoostRegressor RMSE: 0.1462195745618123

# %%
# Create predictions
predictions = np.exp(xgb_reg.predict(X_test_scaled))
my_pred_xgb = pd.DataFrame({'Id': test_df.index, 'SalePrice': predictions})

# Create CSV file
#my_pred_xgb.to_csv('pred_xgb.csv', index=False)
my_pred_xgb
# Out:
#         Id      SalePrice
# 0     1461  131035.195312
# 1     1462  163451.796875
# 2     1463  186329.859375
# 3     1464  197061.625000
# 4     1465  191928.984375
# ...    ...            ...
# 1454  2915   81060.328125
# 1455  2916   82552.750000
# 1456  2917  166784.046875
# 1457  2918  119906.507812
# 1458  2919  227131.718750
#
# [1459 rows x 2 columns]

# %%
# LIGHTGBM# Instantiate reg
from lightgbm import LGBMRegressor

lgbm_reg = LGBMRegressor(
    objective='regression',
    num_leaves=4,
    learning_rate=0.01,
    n_estimators=5000,
    max_bin=200,
    bagging_fraction=0.75,
    bagging_freq=5,
    bagging_seed=7,
    feature_fraction=0.2,
    feature_fraction_seed=7,
    verbose=-1,
    #min_data_in_leaf=2,
    #min_sum_hessian_in_leaf=11
)

# Fit the model to the data
lgbm_reg.fit(X_train, y_train)

# Predict on the test set from our training set
y_pred_lgbm_reg = lgbm_reg.predict(X_test)
print("LGBMRegressor RMSE:",sqrt(mean_squared_error(y_test, y_pred)))

# Create predictions
predictions = np.exp(lgbm_reg.predict(X_test_scaled))
my_pred_lgbm = pd.DataFrame({'Id': test_df.index, 'SalePrice': predictions})

# Create CSV file
#my_pred_lgbm.to_csv('pred_lgbm.csv', index=False)
my_pred_lgbm
# Out:
# LGBMRegressor RMSE: 0.1439313985757928
#         Id      SalePrice
# 0     1461  126841.599594
# 1     1462  163018.510003
# 2     1463  186994.030798
# 3     1464  198186.849195
# 4     1465  200260.618359
# ...    ...            ...
# 1454  2915   84934.308077
# 1455  2916   87822.361936
# 1456  2917  168703.225458
# 1457  2918  123506.745225
# 1458  2919  225095.160067
#
# [1459 rows x 2 columns]

# %%
# STACKED REGRESSION
from sklearn.ensemble import StackingRegressor

# Instantiate reg
stregr = StackingRegressor(
    estimators=[
        ('xgb', xgb_reg),
        ('estc', elastic_reg),
        ('lasso', lasso_reg),
        ('lgbm', lgbm_reg)
    ],
    final_estimator=lgbm_reg,
    passthrough=True  # Equivalent to use_features_in_secondary=True
)
# Fit the model to the data
stack_reg=stregr.fit(X_train, y_train)

# Predict on the test set from our training set
y_pred = stack_reg.predict(X_test)
print("StackedRegressor RMSE:",sqrt(mean_squared_error(y_test, y_pred)))

# Create predictions
predictions = np.exp(stack_reg.predict(X_test_scaled))
my_pred_stacked = pd.DataFrame({'Id': test_df.index, 'SalePrice': predictions})
my_pred_stacked
# Out:
# StackedRegressor RMSE: 0.14358165573032533
#         Id      SalePrice
# 0     1461  129684.846318
# 1     1462  160128.200223
# 2     1463  182486.097399
# 3     1464  206521.839060
# 4     1465  199201.847464
# ...    ...            ...
# 1454  2915   85653.682321
# 1455  2916   87179.990538
# 1456  2917  170349.288199
# 1457  2918  120869.217375
# 1458  2919  226337.967040
#
# [1459 rows x 2 columns]

# %%
#ANN with Keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(32,activation='relu',input_dim=X_train.shape[1]))
model.add(Dense(units=317,activation='relu'))
model.add(Dense(units=300,activation='relu'))
# Adding the fourth hidden layer
model.add(Dense(units = 200, activation = 'relu'))

# Adding the fifth hidden layer
model.add(Dense(units = 200, activation = 'relu'))

# Adding the sixth hidden layer
model.add(Dense(units = 100, activation = 'relu'))

# Adding the seventh hidden layer
model.add(Dense(units = 100, activation = 'relu'))

# Adding the output layer
model.add(Dense(units = 1))

model.compile(optimizer='adam',loss='mean_squared_error')

#Fitting
model.fit(X_train,y_train,batch_size=10,epochs=200)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/200
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 115.2990
# Epoch 2/200
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 58.4842
# Epoch 3/200
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 12.9242
# Epoch 4/200
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.2187
# Epoch 5/200
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 13.9944
# Epoch 6/200
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 28.0312
# Epoch 7/200
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 10.6073
# Epoch 8/200
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.7824
# Epoch 9/200
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.3975
# ...

# %%
y_pred = model.predict(X_test)
print("ANNRegressor RMSE:",sqrt(mean_squared_error(y_test, y_pred)))

# Create predictions
predictions_ann = np.exp(model.predict(X_test_scaled))
predictions_ann = np.concatenate(predictions_ann, axis=0 )
my_pred_ann = pd.DataFrame({'Id': test_df.index, 'SalePrice': predictions_ann})
my_pred_ann
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# ANNRegressor RMSE: 0.16112566550992782
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#         Id      SalePrice
# 0     1461  108847.171875
# 1     1462  149613.921875
# 2     1463  177454.531250
# 3     1464  198082.281250
# 4     1465  201220.812500
# ...    ...            ...
# 1454  2915   93307.789062
# 1455  2916   82817.937500
# 1456  2917  142353.656250
# 1457  2918   81879.781250
# 1458  2919  224114.390625
#
# [1459 rows x 2 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
